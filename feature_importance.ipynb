# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import data

from sklearn.decomposition import PCA,TruncatedSVD,NMF
from sklearn.feature_selection import (chi2, f_classif,mutual_info_classif,
                                        SelectKBest,SelectFromModel,VarianceThreshold,RFECV)
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV,StratifiedKFold
from sklearn.pipeline import Pipeline, FeatureUnion,TransformerMixin
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.ensemble import (AdaBoostClassifier,BaggingClassifier,ExtraTreesClassifier,
                              GradientBoostingClassifier,RandomForestClassifier,VotingClassifier)
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier
from sklearn.svm import LinearSVC,SVC,NuSVC
from sklearn.naive_bayes import BernoulliNB,GaussianNB,MultinomialNB
from sklearn.linear_model import LogisticRegression,RidgeClassifier,SGDClassifier
from sklearn.neighbors import KNeighborsClassifier,RadiusNeighborsClassifier

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
# Drop same or zero columns
X_train,y_train,X_test = data.load_data()
same_columns = []
for i in range(0,595):
    if i not in same_columns:
        counter = i + 1
        while counter < 595:
            if X_train.iloc[:,i].equals(X_train.iloc[:,counter]):
                same_columns.append(counter)
            counter += 1
same_columns.append(2)
same_columns = list(set(same_columns))
for i in same_columns:
    X_train.drop(columns='X'+str(i+1), axis=1, inplace=True)
    X_test.drop(columns='X'+str(i+1), axis=1, inplace=True)

# %% [markdown]
# ## Calculate Feature Importance using ensemble methods
# ----------

# %%
def calculate_importance(model, X,y):
    selector = SelectFromModel(model, threshold=1e-4)
    selector.fit(X, y)
    support = selector.get_support()
    feature = X.loc[:,support].columns.tolist()
    print(str(len(feature)), 'selected features')
    print(calculate_score(model,X,y))
    return support

def select_k_best(score,X_norm,X,y,k=150):
    selector = SelectKBest(score, k=k)
    selector.fit(X_norm, y)
    support = selector.get_support()
    feature = X.loc[:,support].columns.tolist()
    print(str(len(feature)), 'selected features')
    return support

def calculate_mean_importance(model_list,X,y):
    mean_importances = np.zeros([496])
    for model in model_list:
        model.fit(X_train, y_train)
        if model.feature_importances_.sum() == 1.0:
            mean_importances += model.feature_importances_
        else:
            print(model)
            print(model.feature_importances_.sum())
    return mean_importances/len(model_list)
        
def calculate_score(model,X,y):
    model.fit(X,y)
    y_pred = model.predict(X)
    return accuracy_score(y,y_pred)

# %%
models = []
model = RandomForestClassifier(n_estimators=100, max_depth=5)
models.append(model)
model = AdaBoostClassifier(learning_rate=0.1,n_estimators=100)
models.append(model)
#model = BaggingClassifier(n_estimators=100)
#selector = SelectFromModel(model, prefit=False)
model = ExtraTreesClassifier(n_estimators=100)
models.append(model)
model = GradientBoostingClassifier(learning_rate=0.1,n_estimators=100)
models.append(model)
model = DecisionTreeClassifier(max_depth=7)
models.append(model)
model = ExtraTreeClassifier(max_depth=15)
models.append(model)
model = XGBClassifier()
models.append(model)

average_importances = calculate_mean_importance(models,X_train,y_train)

model = LogisticRegression(C=10)
models.append(model)
model = LGBMClassifier()
models.append(model)

support = []

selector = VarianceThreshold(0.0008)
selector.fit(X_train)
support.append(selector.get_support())
feature = X_train.loc[:,selector.get_support()].columns.tolist()
print(str(len(feature)), 'selected features')

X_norm = MinMaxScaler().fit_transform(X_train)
support.append(select_k_best(chi2,X_norm,X_train, y_train, k=100))
support.append(select_k_best(f_classif,X_norm,X_train, y_train))
support.append(select_k_best(mutual_info_classif,X_norm, X_train, y_train))

#rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=5)
selector = RFECV(LogisticRegression(C=0.1), step=1, cv=5,scoring='accuracy')
selector = selector.fit(X_norm, y_train)
support.append(selector.support_)
feature = X_train.loc[:,selector.support_].columns.tolist()
print(str(len(feature)), 'selected features')
selector = RFECV(SVC(kernel="linear"), step=1, cv=5,scoring='accuracy')
selector = selector.fit(X_norm, y_train)
support.append(selector.support_)
feature = X_train.loc[:,selector.support_].columns.tolist()
print(str(len(feature)), 'selected features')


for model in models:
    support.append(calculate_importance(model,X_train, y_train))
# Out:
# 388 selected features
# 100 selected features
# 150 selected features
# 150 selected features
# 14 selected features
# 61 selected features
# 445 selected features
# 1.0
# 45 selected features
# 1.0
# 496 selected features
# 1.0
# 158 selected features
# 1.0
# 15 selected features
# 0.9916666666666667
# 39 selected features
# 1.0
# 180 selected features
# 1.0
# 496 selected features
# 0.9083333333333333
# 133 selected features
# 1.0

# %%
average_importances
# Out:
# 1.0000000008897456

# %%
feature_name = X_train.columns.tolist()
voting_dict = {}
voting_dict['Feature'] = feature_name
for i,vector in enumerate(support):
    voting_dict[i] = vector

# put all selection together
feature_selection_df = pd.DataFrame(voting_dict)
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
feature_selection_df['Average'] = average_importances
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Average','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(100)
# Out:
#     Feature      0      1      2      3      4      5     6      7     8  \
# 1      X163   True   True   True   True  False  False  True   True  True
# 2       X33   True   True   True   True  False  False  True   True  True
# 3      X453   True   True   True  False   True   True  True   True  True
# 4      X201   True   True   True  False   True   True  True  False  True
# 5      X581  False   True   True   True   True   True  True   True  True
# 6      X243   True   True   True   True   True  False  True   True  True
# 7      X281   True   True   True   True  False  False  True   True  True
# 8      X221   True   True   True  False  False  False  True   True  True
# 9      X238  False   True   True  False   True   True  True   True  True
# 10      X66   True   True   True   True   True  False  True   True  True
# 11     X347  False   True   True   True  False   True  True   True  True
# 12     X210   True   True   True   True  False   True  True   True  True
# 13     X227  False   True   True  False   True   True  True   True  True
# 14     X474   True   True   True  False  False   True  True  False  True
# 15     X144   True   True   True  False   True   True  True  False  True
# 16     X454  False   True   True  False  False  False  True   True  True
# 17     X266   True   True   True  False  False  False  True   True  True
# 18     X427   True   True   True  False  False   True  True   True  True
# 19     X138  False   True   True  False   True   True  True   True  True
# 20     X558   True   True   True   True   True  False  True  False  True
# 21     X503   True   True   True   True  False  False  True  False  True
# 22     X387   True   True   True  False  False  False  True   True  True
# 23     X175   True  False   True  False  False   True  True   True  True
# 24     X336   True   True   True  False  False   True  True  False  True
# 25      X38   True   True   True   True  False   True  True  False  True
# 26     X485   True   True   True  False  False   True  True  False  True
# 27     X364   True  False   True   True  False  False  True  False  True
# 28     X143   True  False  False   True  False  False  True  False  True
# 29     X426   True   True   True  False  False  False  True   True  True
# 30     X262   True   True   True   True  False  False  True   True  True
# ..      ...    ...    ...    ...    ...    ...    ...   ...    ...   ...
# 71     X164   True  False  False   True  False  False  True  False  True
# 72     X306  False  False  False   True  False   True  True  False  True
# 73     X233  False   True   True   True   True  False  True  False  True
# 74     X584   True   True   True  False   True  False  True  False  True
# 75      X49   True   True   True   True  False  False  True  False  True
# 76     X551   True   True   True   True  False  False  True  False  True
# 77     X390   True   True   True  False   True   True  True  False  True
# 78     X470   True  False  False  False  False   True  True  False  True
# 79     X254   True  False  False   True  False   True  True  False  True
# 80      X71   True  False   True   True  False  False  True  False  True
# 81     X554   True   True   True   True  False  False  True  False  True
# 82     X174   True  False  False  False  False  False  True   True  True
# 83     X408   True  False  False  False  False  False  True  False  True
# 84     X419   True  False  False   True  False  False  True  False  True
# 85     X325  False  False  False  False  False   True  True  False  True
# 86     X459   True  False  False   True  False  False  True   True  True
# 87     X133  False  False  False  False  False  False  True   True  True
# 88     X326   True  False  False  False  False   True  True  False  True
# 89       X5   True  False  False   True  False  False  True  False  True
# 90     X176   True  False  False   True  False  False  True  False  True
# 91     X154  False  False  False  False  False   True  True  False  True
# 92     X137   True  False  False   True  False  False  True  False  True
# 93      X48   True  False  False   True  False  False  True  False  True
# 94     X448   True  False  False  False  False  False  True   True  True
# 95     X279   True  False  False   True  False  False  True  False  True
# 96     X188   True  False  False  False  False   True  True   True  True
# 97     X346   True   True   True  False  False   True  True  False  True
# 98     X595   True   True   True   True  False  False  True  False  True
# 99     X220  False  False  False  False  False   True  True   True  True
# 100     X11   True  False  False   True  False  False  True   True  True
#
#          9     10     11     12    13     14  Total   Average
# 1     True   True  False   True  True   True     12  0.033836
# 2     True   True  False   True  True   True     12  0.021938
# 3     True  False  False   True  True   True     12  0.020994
# 4     True   True  False   True  True   True     12  0.014624
# 5     True  False  False   True  True   True     12  0.009608
# 6     True  False  False   True  True   True     12  0.006006
# 7     True  False  False   True  True   True     11  0.025387
# 8     True  False   True   True  True   True     11  0.010215
# 9     True  False  False   True  True   True     11  0.007548
# 10    True  False  False   True  True  False     11  0.004694
# 11    True  False  False   True  True   True     11  0.004507
# 12    True  False  False  False  True   True     11  0.003577
# 13    True  False  False   True  True   True     11  0.003278
# 14    True  False   True   True  True   True     11  0.001203
# 15    True  False  False   True  True   True     11  0.001075
# 16    True   True  False   True  True   True     10  0.038541
# 17    True  False  False   True  True   True     10  0.016310
# 18    True  False  False  False  True   True     10  0.007796
# 19    True  False  False   True  True  False     10  0.006266
# 20    True  False  False   True  True  False     10  0.005996
# 21    True  False   True  False  True   True     10  0.004663
# 22    True  False  False   True  True   True     10  0.003686
# 23    True  False  False   True  True   True     10  0.003456
# 24    True  False  False   True  True   True     10  0.003271
# 25   False  False  False   True  True   True     10  0.001674
# 26    True  False  False   True  True   True     10  0.001088
# 27    True   True  False   True  True   True     10  0.000681
# 28    True   True  False   True  True   True      9  0.019408
# 29    True  False  False   True  True  False      9  0.011336
# 30   False  False  False   True  True  False      9  0.010539
# ..     ...    ...    ...    ...   ...    ...    ...       ...
# 71    True  False  False   True  True   True      8  0.001186
# 72    True  False  False   True  True   True      8  0.001100
# 73   False  False   True  False  True  False      8  0.001097
# 74   False  False   True  False  True  False      8  0.000831
# 75   False  False  False  False  True   True      8  0.000789
# 76    True  False  False  False  True  False      8  0.000699
# 77   False  False  False  False  True  False      8  0.000655
# 78   False  False   True   True  True   True      8  0.000620
# 79    True  False  False  False  True   True      8  0.000573
# 80    True  False  False  False  True   True      8  0.000322
# 81   False  False  False  False  True   True      8  0.000205
# 82   False  False  False   True  True   True      7  0.013832
# 83    True   True  False   True  True  False      7  0.013785
# 84    True   True  False  False  True  False      7  0.011961
# 85   False  False   True   True  True   True      7  0.006747
# 86    True  False  False  False  True  False      7  0.006390
# 87    True  False   True  False  True   True      7  0.005939
# 88   False  False  False   True  True   True      7  0.005739
# 89   False  False  False   True  True   True      7  0.005661
# 90    True  False  False   True  True  False      7  0.005599
# 91    True  False  False   True  True   True      7  0.005137
# 92    True  False  False   True  True  False      7  0.004987
# 93    True  False  False   True  True  False      7  0.004704
# 94    True  False  False   True  True  False      7  0.004551
# 95    True  False  False  False  True   True      7  0.003938
# 96   False  False  False  False  True   True      7  0.003666
# 97   False  False  False  False  True  False      7  0.002946
# 98   False  False  False  False  True  False      7  0.002818
# 99    True  False  False   True  True  False      7  0.002752
# 100   True  False  False  False  True  False      7  0.002593
#
# [100 rows x 18 columns]

# %%
selected_index = feature_selection_df.Feature[0:50].tolist()

# %%
model = LogisticRegression(dual=True)
gridParams = {
    'C':[0.001,0.01,0.1,1,10,30,50,100,1000],
    'max_iter':[100,1000],
}
grid = GridSearchCV(model, gridParams,
                    verbose=0,
                    cv=5,
                    n_jobs=2)
grid.fit(X_train.loc[:,selected_index],y_train)
grid.best_score_
# Out:
# 0.7166666666666667

# %%
y_pred = grid.best_estimator_.predict(X_train.loc[:,selected_index])
accuracy_score(y_pred,y_train)
# Out:
# 0.8083333333333333

# %%
y_pred = grid.best_estimator_.predict(X_test.loc[:,selected_index])
data.write_output(y_pred.reshape(-1,1))

# %%
params = {'boosting_type': 'gbdt',
          'max_depth' : 3,
          'objective': 'binary',
          'nthread': 3, # Updated from nthread
          'num_leaves': 31,
          'learning_rate': 0.05,
          'max_bin': 128,
          'subsample_for_bin': 200,
          'subsample': 1,
          'subsample_freq': 1,
          'colsample_bytree': 0.8,
          'reg_alpha': 5,
          'reg_lambda': 10,
          'min_split_gain': 0.5,
          'min_child_weight': 1,
          'min_child_samples': 5,
          'scale_pos_weight': 1,
          'num_class' : 1,
          'metric' : 'binary_error'
         }

# Create parameters to search
gridParams = {
    'learning_rate': [0.005],
    'n_estimators': [40,100],
    'num_leaves': [6,8,12,16],
    'boosting_type' : ['gbdt'],
    'colsample_bytree' : [0.65, 0.66],
    'subsample' : [0.7,0.75],
    'reg_alpha' : [1,1.2],
    'reg_lambda' : [1,1.2,1.4],
    'lambda_l1': [1,1,5,2,3,5]
    }

# Create classifier to use. Note that parameters have to be input manually
# not as a dict!
mdl = LGBMClassifier(boosting_type= 'gbdt',
          objective = 'binary',
          n_jobs = 3, # Updated from 'nthread'
          silent = True,
          max_depth = params['max_depth'],
          max_bin = params['max_bin'],
          subsample_for_bin = params['subsample_for_bin'],
          subsample = params['subsample'],
          subsample_freq = params['subsample_freq'],
          min_split_gain = params['min_split_gain'],
          min_child_weight = params['min_child_weight'],
          min_child_samples = params['min_child_samples'],
          scale_pos_weight = params['scale_pos_weight'])

# %%
grid = GridSearchCV(mdl, gridParams,
                    verbose=0,
                    cv=4,
                    n_jobs=2)

# %%
grid.fit(X_train.loc[:,selected_index],y_train)
grid.best_score_
# Out:
# 0.65

# %%
y_pred = grid.best_estimator_.predict(X_train.loc[:,selected_index])
accuracy_score(y_pred,y_train)
# Out:
# 0.95

# %%
y_pred = grid.best_estimator_.predict(X_test.loc[:,selected_index])
data.write_output(y_pred.reshape(-1,1))

# %%
C_OPTIONS = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]
gamma = [1,0.1,0.001,0.0001]
param_grid = {
        'C': C_OPTIONS,
        'gamma':gamma,
        'kernel':['linear','rbf']
    }

# %%
k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)
grid = GridSearchCV(SVC(), n_jobs=1, param_grid=param_grid, scoring="accuracy",cv=k_fold)
grid.fit(X_train.loc[:,selected_index],y_train)
grid.best_score_
# Out:
# 0.6666666666666666

# %%
y_pred = grid.best_estimator_.predict(X_test.loc[:,selected_index])
data.write_output(y_pred.reshape(-1,1))
y_pred = grid.best_estimator_.predict(X_train.loc[:,selected_index])
accuracy_score(y_pred,y_train)
# Out:
# 0.8083333333333333

# %%
model_neighbors = KNeighborsClassifier()
k_range = np.arange(1,31)
weights = ["uniform","distance"]
param_grid = dict(n_neighbors = k_range, weights = weights)
grid = GridSearchCV(model_neighbors, param_grid,scoring = "accuracy", cv = 5)
grid.fit(X_train.loc[:,selected_index],y_train)
grid.best_score_
# Out:
# 0.6083333333333333

# %%
# Classify train and test
x_train,y,x_test = data.load_data()
all_data = pd.concat([x_train,x_test])
all_data.shape
all_y = np.concatenate((np.ones([120,1], dtype=int),np.zeros([80,1], dtype=int)))

clf = GradientBoostingClassifier()
clf.fit(all_data, all_y)
y_pred = clf.predict(all_data)
accuracy_score(all_y,y_pred)
feature_name = all_data.columns.tolist()
df_important = pd.DataFrame({"feature":feature_name,"importance":clf.feature_importances_})
effect = df_important.sort_values(by="importance", ascending=False).iloc[0:100,:]
features_effect = effect.feature.tolist()
feature_selection_without = feature_selection_df.loc[feature_selection_df["Feature"].isin(features_effect)]
