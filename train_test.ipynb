# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle
from sklearn import svm
from sklearn import linear_model
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest,SelectPercentile, chi2
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB

# %%
import data
train_x, train_y, test_x = data.load_data()
train_x.shape
# Out:
# (120, 595)

# %%
def training_svc(X, y, k=5):
    accuracy_total = 0
    kf = KFold(n_splits=k)
    kf.get_n_splits(X)
    for i,(train_index, test_index) in enumerate(kf.split(X)):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        clf = svm.SVC()
        #clf = svm.SVC(random_state=0, tol=1e-5)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        accuracy = accuracy_score(y_pred, y_test)
        #print("Accuracy for fold-" + str(i) + " is", accuracy)
        accuracy_total += accuracy
    return accuracy_total /k

# %%
def training_linear(X, y, k=5):
    accuracy_total = 0
    kf = KFold(n_splits=k)
    kf.get_n_splits(X)
    for i,(train_index, test_index) in enumerate(kf.split(X)):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        #clf = GaussianNB()
        clf = LinearDiscriminantAnalysis()
        #clf = KNeighborsClassifier(n_neighbors=16)
        #clf = DecisionTreeClassifier()
        #clf = linear_model.SGDClassifier(max_iter=1000, tol=1e-3)
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        accuracy = accuracy_score(y_pred, y_test)
        #print("Accuracy for fold-" + str(i) + " is", accuracy)
        accuracy_total += accuracy
    return accuracy_total/k

# %%
max_accuracy = 0
max_percentile = -1
for i in range(1,250):
    bestfeatures = SelectKBest(score_func=chi2, k=i)
    selected_X = bestfeatures.fit_transform(data_X,data_Y)
    Y = data_Y.values
    acc1 = training_linear(selected_X, Y, k=5)
    if(max_accuracy < acc1):
        max_accuracy = acc1
        max_percentile = i
    print(i, acc1)
print("Top k =", max_percentile, "accuracy= ", max_accuracy)
# Out:
# 1 0.6000000000000001
# 2 0.5833333333333334
# 3 0.5916666666666668
# 4 0.5833333333333334
# 5 0.5666666666666667
# 6 0.55
# 7 0.5333333333333333
# 8 0.5333333333333333
# 9 0.5333333333333333
# 10 0.5083333333333333
# 11 0.5166666666666666
# 12 0.5333333333333334
# 13 0.5499999999999999
# 14 0.5666666666666667
# 15 0.5666666666666667
# 16 0.5666666666666667
# 17 0.5666666666666667
# 18 0.575
# 19 0.575
# 20 0.55
# /home/okur/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /home/okur/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /home/okur/anaconda3/lib/python3.7/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# ...

# %%
def training_all(X_train, y_train, X_test, k):
    accuracy_total = 0
    #clf = KNeighborsClassifier(n_neighbors=10)
    #clf = linear_model.SGDClassifier(max_iter=1000, tol=1e-3)
    clf = LogisticRegression()
    clf.fit(X_train,y_train)
    y_pred_real = clf.predict(X_test)
    y_pred = clf.predict(X_train)
    result = np.ndarray(shape=(80,2),dtype=int)
    for i in range (1,81):
        result[i-1,0] = int(i)
        result[i-1,1] = int(y_pred_real[i-1])
    #np.savetxt("submit.csv", np.concatenate(np.arange(1,81),y_pred_real), delimiter=",", header='ID,Predicted', comments='')
    np.savetxt("ldasubmit{i}.csv", result, delimiter=",", header='ID,Predicted', comments='', fmt='%1d')
    accuracy = accuracy_score(y_pred, y_train)
    #print("Accuracy for fold-" + str(i) + " is", accuracy)
    accuracy_total += accuracy
    return accuracy_total

# %%
dataset = pd.read_csv("train.csv")
dataset = shuffle(dataset)
data_X = dataset.iloc[:,:595]
data_Y = dataset.iloc[:,-1]

max_accuracy = 0
max_percentile = -1
for i in range(213,214):
    bestfeatures = SelectKBest(score_func=chi2, k=i)
    index = bestfeatures.fit(data_X,data_Y)
    dfscores = pd.DataFrame(index.scores_)
    dfcolumns = pd.DataFrame(data_X.columns)
    featureScores = pd.concat([dfcolumns,dfscores],axis=1)
    featureScores.columns = ['Specs','Score']  #naming the dataframe columns
    selected_column = featureScores.nlargest(i,'Score').iloc[:,0]  #print 50 best features
    selected_X =  data_X.loc[:,selected_column]
    selected_test = test.loc[:,selected_column]
    #print(selected_X)
    Y = data_Y.values
    acc = training_all(selected_X, Y, selected_test, i)
    if(max_accuracy < acc):
        max_accuracy = acc
        max_percentile = i
    #print("k =", i, "accuracy= ", acc)
print("Top k =", max_percentile, "accuracy= ", max_accuracy)
# Out:
# Top k = 213 accuracy=  0.7166666666666667
# /home/okur/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
def training_logistic(X,y, k=5):
    accuracy_total = 0
    kf = KFold(n_splits=k)
    kf.get_n_splits(X)
    for i,(train_index, test_index) in enumerate(kf.split(X)):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        logreg = LogisticRegression()
        logreg.fit(X_train, y_train)
        accuracy = logreg.score(X_test, y_test)
        accuracy_total += accuracy
    return accuracy_total/k

# %%
index
# Out:
# SelectKBest(k=213, score_func=<function chi2 at 0x7f341dbc71e0>)
